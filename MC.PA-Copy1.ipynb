# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy.stats import norm

# %%
# TTE    BNP      MC.PA

# %%
df = pd.read_csv("MC.PA.csv")

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-12-27  683.299988  692.700012  682.299988  690.200012  679.456604
# 1  2022-12-28  692.299988  694.700012  685.799988  686.599976  675.912659
# 2  2022-12-29  684.700012  699.000000  682.200012  696.500000  685.658569
# 3  2022-12-30  696.599976  696.599976  676.599976  679.900024  669.316956
# 4  2023-01-02  689.400024  695.000000  685.099976  694.099976  683.295837
#
#      Volume
# 0  249850.0
# 1  196630.0
# 2  198655.0
# 3  272368.0
# 4  194703.0

# %% [markdown]
# ### Outliers

# %%
def find_outliers_iqr(data, column_name):
    # Calculate quartiles and IQR for the specified column
    Q1 = data[column_name].quantile(0.25)
    Q3 = data[column_name].quantile(0.75)
    IQR = Q3 - Q1

    # Calculate the lower and upper bounds to identify outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Find outliers in the specified column
    outliers = data[(data[column_name] < lower_bound) | (data[column_name] > upper_bound)]
    
    return outliers

# %%
find_outliers_iqr(df , "Open")
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
find_outliers_iqr(df , "High")
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
find_outliers_iqr(df , "Low")
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
find_outliers_iqr(df , "Close")
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
find_outliers_iqr(df , "Adj Close")
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
find_outliers_iqr(df , "Volume")
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 43   2023-02-24  811.400024  812.700012  777.299988  777.299988  765.200806
# 54   2023-03-13  803.700012  805.799988  775.500000  781.700012  769.532349
# 56   2023-03-15  797.599976  800.400024  767.599976  774.700012  762.641357
# 57   2023-03-16  785.299988  809.299988  776.700012  801.700012  789.221069
# 58   2023-03-17  805.000000  808.000000  784.500000  787.299988  775.045166
# 108  2023-05-31  818.299988  828.500000  807.599976  813.900024  807.497742
# 120  2023-06-16  848.500000  872.400024  845.500000  868.599976  861.767456
# 148  2023-07-26  821.000000  826.400024  804.500000  810.000000  803.628418
# 178  2023-09-06  757.299988  757.500000  723.599976  731.500000  725.745911
# 185  2023-09-15  759.400024  772.400024  757.400024  761.200012  755.212280
# 203  2023-10-11  691.000000  699.200012  671.500000  686.099976  680.703003
# 204  2023-10-12  689.799988  690.299988  673.299988  675.000000  669.690369
# 239  2023-11-30  693.299988  703.099976  682.200012  702.700012  697.172485
# 250  2023-12-15  749.799988  755.299988  745.599976  748.400024  748.400024
#
#         Volume
# 43    839007.0
# 54    656071.0
# 56    658997.0
# 57    600374.0
# 58    932225.0
# 108   859625.0
# 120  1017309.0
# 148   751898.0
# 178   699773.0
# 185  1180906.0
# 203  1544205.0
# 204   628130.0
# 239  1013823.0
# 250   822557.0

# %%
def create_boxplot_with_outliers(data, column_name):
    # Finding outliers in the specified column
    outliers = find_outliers_iqr(data, column_name)

    # Creating a boxplot to visualize the specified column and its outliers
    plt.figure(figsize=(8, 6))
    plt.boxplot(data[column_name])
    plt.title(f'Boxplot of "{column_name}" Column with Outliers')
    plt.ylabel('Values')
    plt.xlabel(column_name)
    plt.grid(True)

    # Highlighting outliers on the boxplot
    if not outliers.empty:
        plt.scatter(outliers.index + 1, outliers[column_name], color='red', label='Outliers')
        plt.legend()

    plt.show()

# %%
create_boxplot_with_outliers(df , "Volume")

# %% [markdown]
# ## Missing Values

# %%
rows_with_na = df[df.isna().any(axis=1)]

print("Rows with empty or NA cells:")
print(rows_with_na)
# Out:
# Rows with empty or NA cells:
#            Date  Open  High  Low  Close  Adj Close  Volume
# 109  2023-06-01   NaN   NaN  NaN    NaN        NaN     NaN
# 156  2023-08-07   NaN   NaN  NaN    NaN        NaN     NaN

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  254.000000  254.000000  254.000000  254.000000  254.000000
# mean   786.608267  794.562991  779.010630  787.028346  779.157878
# std     64.516882   64.440245   64.310422   64.321832   63.033885
# min    660.599976  669.799988  655.000000  660.599976  655.403625
# 25%    726.774994  737.925018  720.749985  731.699997  725.937576
# 50%    802.100006  809.649994  791.550018  801.800018  789.762482
# 75%    837.774994  845.150009  827.650024  836.449982  828.382157
# max    894.500000  904.599976  891.599976  902.000000  887.959778
#
#              Volume
# count  2.540000e+02
# mean   3.635752e+05
# std    1.622619e+05
# min    1.098630e+05
# 25%    2.732502e+05
# 50%    3.238365e+05
# 75%    4.040958e+05
# max    1.544205e+06

# %%
def visualize_histogram(data, column_name):
    plt.figure(figsize=(6, 4))
    plt.hist(data[column_name])
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.title(f'Histogram of "{column_name}" Column')
    plt.tight_layout()
    plt.show()

    
def visualize_boxplot(data, column_name):
    plt.figure(figsize=(6, 8))
    plt.boxplot(data[column_name])
    plt.title(f'Boxplot of "{column_name}" Column')
    plt.ylabel('Values')
    plt.xlabel(column_name)
    plt.show()
    
    
def visualize_time_series_limited_dates(data, x_column, y_column, x_label, num_dates=5):
    # Selecting the date column and sorting it
    dates = data[x_column].sort_values()
    
    # Calculating the range of dates
    date_range = np.linspace(0, len(dates) - 1, num_dates, dtype=int)
    
    # Selecting only the necessary dates for visualization
    selected_dates = dates.iloc[date_range]
    
    # Filtering the DataFrame for these selected dates
    filtered_data = data[data[x_column].isin(selected_dates)]
    
    plt.figure(figsize=(10, 6))
    plt.plot(filtered_data[x_column], filtered_data[y_column])
    plt.title(f'{y_column} over {x_label}')
    plt.xlabel(x_label)
    plt.ylabel(y_column)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
    

def visualize_column_correlation(data, column_name):
    numeric_columns = data.select_dtypes(include=[np.number]).columns
    numeric_columns = numeric_columns.drop(column_name)
    correlations = data[numeric_columns].corrwith(data[column_name])
    corr_df = pd.DataFrame({'Correlation': correlations})
    corr_df = corr_df.sort_values(by='Correlation', ascending=False)
    
    cmap = np.random.choice(plt.colormaps())
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(data[corr_df.index].corr(), annot=True, cmap=cmap, fmt='.2f')
    plt.title(f'Correlation Heatmap of {column_name} with Numeric Columns')
    plt.show()

# %%
# Open

# %%
df["Open"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 256 entries, 0 to 255
# Series name: Open
# Non-Null Count  Dtype
# --------------  -----
# 254 non-null    float64
# dtypes: float64(1)
# memory usage: 2.1 KB

# %%
visualize_histogram(df, "Open")

# %%
visualize_boxplot(df , "Open")

# %%
visualize_time_series(df , "Date" , "Open")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 visualize_time_series(df , "Date" , "Open")
#
# NameError: name 'visualize_time_series' is not defined

# %%
oldest_date = df['Date'].min()
newest_date = df['Date'].max()

print("Oldest Date:", oldest_date)
print("Newest Date:", newest_date)
# Out:
# Oldest Date: 2022-12-27
# Newest Date: 2023-12-22

# %%
visualize_column_correlation(df , "Open")

# %%
# High

# %%
df["High"].describe()
# Out:
# count    254.000000
# mean     794.562991
# std       64.440245
# min      669.799988
# 25%      737.925018
# 50%      809.649994
# 75%      845.150009
# max      904.599976
# Name: High, dtype: float64

# %%
visualize_histogram(df, "High")

# %%
visualize_boxplot(df , "High")

# %%
visualize_time_series(df , "Date" , "High")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 visualize_time_series(df , "Date" , "High")
#
# NameError: name 'visualize_time_series' is not defined

# %%
oldest_date = df['Date'].min()
newest_date = df['Date'].max()

print("Oldest Date:", oldest_date)
print("Newest Date:", newest_date)
# Out:
# Oldest Date: 2022-12-27
# Newest Date: 2023-12-22

# %%
visualize_column_correlation(df , "High")

# %%
# Low

# %%
df["Low"].describe()
# Out:
# count    254.000000
# mean     779.010630
# std       64.310422
# min      655.000000
# 25%      720.749985
# 50%      791.550018
# 75%      827.650024
# max      891.599976
# Name: Low, dtype: float64

# %%
visualize_histogram(df, "Low")

# %%
visualize_boxplot(df , "Low")

# %%
visualize_time_series(df , "Date" , "Low")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 visualize_time_series(df , "Date" , "Low")
#
# NameError: name 'visualize_time_series' is not defined

# %%
visualize_column_correlation(df , "Low")

# %%
# Close

# %%
df["Close"].describe()
# Out:
# count    254.000000
# mean     787.028346
# std       64.321832
# min      660.599976
# 25%      731.699997
# 50%      801.800018
# 75%      836.449982
# max      902.000000
# Name: Close, dtype: float64

# %%
visualize_histogram(df, "Close")

# %%
visualize_boxplot(df , "Close")

# %%
visualize_time_series(df , "Date" , "Close")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 visualize_time_series(df , "Date" , "Close")
#
# NameError: name 'visualize_time_series' is not defined

# %%
visualize_column_correlation(df , "Close")

# %%
# Adj Close

# %%
df["Adj Close"].describe()
# Out:
# count    254.000000
# mean     779.157878
# std       63.033885
# min      655.403625
# 25%      725.937576
# 50%      789.762482
# 75%      828.382157
# max      887.959778
# Name: Adj Close, dtype: float64

# %%
visualize_histogram(df, "Adj Close")

# %%
visualize_boxplot(df , "Adj Close")

# %%
visualize_time_series(df , "Date" , "Adj Close")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 visualize_time_series(df , "Date" , "Adj Close")
#
# NameError: name 'visualize_time_series' is not defined

# %%
visualize_column_correlation(df , "Adj Close")

# %%
# Volume

# %%
df["Volume"].describe()
# Out:
# count    2.540000e+02
# mean     3.635752e+05
# std      1.622619e+05
# min      1.098630e+05
# 25%      2.732502e+05
# 50%      3.238365e+05
# 75%      4.040958e+05
# max      1.544205e+06
# Name: Volume, dtype: float64

# %%
visualize_histogram(df, "Volume")

# %%
visualize_boxplot(df , "Volume")

# %%
visualize_time_series(df , "Date" , "Volume")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 visualize_time_series(df , "Date" , "Volume")
#
# NameError: name 'visualize_time_series' is not defined

# %%
visualize_column_correlation(df , "Volume")

# %% [markdown]
# ## Varience

# %%
def calculate_column_variance(data, column_name):
    column_variance = data[column_name].var()
    return column_variance

def calculate_column_covariance(data, column):
    numeric_columns = data.select_dtypes(include=[np.number]).columns.drop(column)
    covariances = {col: data[[column, col]].cov().iloc[0, 1] for col in numeric_columns}
    print(f"Covariance of '{column}' with other columns:")
    for col, cov in covariances.items():
        print(f"{col}: {cov:.4f}")

# %%
# Open

# %%
calculate_column_variance(df , "Open")
# Out:
# 4162.428041521034

# %%
calculate_column_covariance(df , "Open")
# Out:
# Covariance of 'Open' with other columns:
# High: 4137.9702
# Low: 4127.3087
# Close: 4099.7422
# Adj Close: 4014.1722
# Volume: -1513718.3174

# %%
# High

# %%
calculate_column_variance(df , "High")
# Out:
# 4152.545193711787

# %%
calculate_column_covariance(df , "High")
# Out:
# Covariance of 'High' with other columns:
# Open: 4137.9702
# Low: 4127.0863
# Close: 4126.1533
# Adj Close: 4038.0292
# Volume: -1326571.3628

# %%
# Low

# %%
calculate_column_variance(df , "Low")
# Out:
# 4135.830335666019

# %%
calculate_column_covariance(df , "Low")
# Out:
# Covariance of 'Low' with other columns:
# Open: 4127.3087
# High: 4127.0863
# Close: 4119.2395
# Adj Close: 4033.0575
# Volume: -1814653.0902

# %%
# Close

# %%
calculate_column_variance(df , "Close")
# Out:
# 4137.298095058903

# %%
calculate_column_covariance(df , "Close")
# Out:
# Covariance of 'Close' with other columns:
# Open: 4099.7422
# High: 4126.1533
# Low: 4119.2395
# Adj Close: 4048.8545
# Volume: -1607369.3727

# %%
# Adj Close

# %%
calculate_column_variance(df , "Adj Close")
# Out:
# 3973.2706568476874

# %%
calculate_column_covariance(df , "Adj Close")
# Out:
# Covariance of 'Adj Close' with other columns:
# Open: 4014.1722
# High: 4038.0292
# Low: 4033.0575
# Close: 4048.8545
# Volume: -1604196.8783

# %%
# Volume

# %%
calculate_column_variance(df , "Volume")
# Out:
# 26328921387.36899

# %%
calculate_column_covariance(df , "Volume")
# Out:
# Covariance of 'Volume' with other columns:
# Open: -1513718.3174
# High: -1326571.3628
# Low: -1814653.0902
# Close: -1607369.3727
# Adj Close: -1604196.8783

# %% [markdown]
# # Beta

# %%
def calculate_beta(data):
    stock_returns = data['Close']
    market_returns = data['Open']
    beta = np.cov(market_returns, stock_returns, ddof=0)[0][1] / np.var(market_returns, ddof=0)
    return beta

# %%
calculate_beta(df)
# Out:
# nan

# %% [markdown]
# # Cac40 Index Hedge

# %%
def calculate_cac40_hedge(data):
    cac40_index = data[['Open']].mean(axis=1)
    beta = np.cov(cac40_index, data['Open'], ddof=0)[0][1] / np.var(cac40_index, ddof=0)
    return beta

# %%
calculate_cac40_hedge(df)
# Out:
# nan

# %% [markdown]
# # Value at Risk

# %% [markdown]
# ## Portfolio VaR

# %%
def calculate_equal_weighted_portfolio_var(df, confidence_level=0.95):
    stock_returns = df['Close'].pct_change().dropna()  # Calculate daily returns
    num_assets = 1  # As 'stock_returns' is a Series, set the number of assets to 1
    
    weights = np.array([1 / num_assets])
    portfolio_variance = np.dot(weights.T, np.dot(stock_returns.var(), weights))

    portfolio_volatility = np.sqrt(portfolio_variance)
    alpha = 1 - confidence_level
    portfolio_var = norm.ppf(alpha) * portfolio_volatility * np.sqrt(1)
    
    return portfolio_var


def calculate_single_stock_var(df, confidence_level=0.95):
    stock_returns = df['Close'].pct_change().dropna()  # Calculate daily returns
    
    var_values = {}
    stock_variance = np.var(stock_returns)
    stock_volatility = np.sqrt(stock_variance)
    
    alpha = 1 - confidence_level
    stock_var = norm.ppf(alpha) * stock_volatility * np.sqrt(1)
        
    var_values['Close'] = stock_var  # Assign the VaR value to the 'Close' key
    
    return var_values

# %%
calculate_equal_weighted_portfolio_var(df)
# Out:
# -0.026792100018797844

# %% [markdown]
# ## Single Stocks VaR

# %%
calculate_single_stock_var(df)
# Out:
# {'Close': -0.0267395148846536}

# %% [markdown]
# # HeatMap

# %%
def create_heatmap(data):
    numeric_data = data.select_dtypes(include=np.number)
#     plt.figure(figsize=(10000, 10000))
    sns.heatmap(numeric_data, cmap='coolwarm', annot=True, fmt='.2f')
    plt.title('Heatmap of Numeric DataFrame Columns')
    plt.xlabel('Columns')
    plt.ylabel('Rows')
    plt.show()

# %%
create_heatmap(df)
